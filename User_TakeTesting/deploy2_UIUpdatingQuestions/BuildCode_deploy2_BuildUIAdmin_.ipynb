# %% [markdown]
# LÀ NGƯỜI DÙNG BẠN MUỐN GIẢI PHÁP NHƯ NÀO?

# %% [markdown]
# Là 1 người dùng lowtech? " nếu sau này muốn chỉnh sửa hay thêm bớt câu hỏi, câu trả lời thì có cách nào sales tự làm được không em?"
#
# ```
# Đề xuất các phương án giải quyết
#
# ### Hướng 1: Sửa cơ chế Start mới load file + Build New UI với chức năng chỉnh sừa file
# 1. Sửa cơ chế hiện tại của code cũ: Ấn `Start` mới bắt đầu đọc file.
#
# 2. Build UI mới:
# - Đọc và sửa file .xlsx
# - File có cơ chế tự động lưu, ctrl Z, ctrl C, ctrl V.
# - ...
#
#
# ### Hướng 2 Link Drive:
# - Thay đổi cách load file, thay vì load file ở local thì load file trên Drive
#
# ### Các phương án khác
# (ít nhất 5 phương án tất cả)
#
# ------------------
# Define kỹ rủi ro, vấn đề, - giải pháp cho rủi ro của từng phương án.
# ```

# %% [markdown]
# LÀ NGƯỜI DÙNG BẠN MUỐN GIẢI PHÁP NHƯ NÀO?

# %% [markdown]
# Là 1 người dùng lowtech? " nếu sau này muốn chỉnh sửa hay thêm bớt câu hỏi, câu trả lời thì có cách nào sales tự làm được không em?"
#
# ```
# Đề xuất các phương án giải quyết
#
# ### Hướng 1: Sửa cơ chế Start mới load file + Build New UI với chức năng chỉnh sừa file
# 1. Sửa cơ chế hiện tại của code cũ: Ấn `Start` mới bắt đầu đọc file.
#
# 2. Build UI mới:
# - Đọc và sửa file .xlsx
# - File có cơ chế tự động lưu, ctrl Z, ctrl C, ctrl V.
# - ...
#
#
# ### Hướng 2 Link Drive:
# - Thay đổi cách load file, thay vì load file ở local thì load file trên Drive
#
# ### Các phương án khác
# (ít nhất 5 phương án tất cả)
#
# ------------------
# Define kỹ rủi ro, vấn đề, - giải pháp cho rủi ro của từng phương án.
# ```

# %% [markdown]
# Dưới đây là các phương án đề xuất cùng với việc định nghĩa kỹ các rủi ro, vấn đề, và giải pháp cho từng phương án:
#
#  Hướng 1: Sửa cơ chế Start mới load file + Build New UI với chức năng chỉnh sửa file
# 1. Sửa cơ chế hiện tại của code cũ: Ấn `Start` mới bắt đầu đọc file
#    - Vấn đề & Rủi ro:
#      - Khó khăn trong việc quản lý bộ nhớ khi đọc file trước hoặc trong quá trình chạy ứng dụng.
#      - Người dùng cần tải lại file khi muốn cập nhật dữ liệu.
#    - Giải pháp:
#      - Thay đổi cơ chế để khi nhấn `Start`, ứng dụng sẽ tải dữ liệu file một cách bất đồng bộ (asynchronous loading) để không làm gián đoạn quá trình hoạt động của ứng dụng.
#      - Kiểm tra tính toàn vẹn của dữ liệu sau khi load để tránh lỗi phát sinh do file bị lỗi hoặc không đúng định dạng.
#
# 2. Build UI mới để đọc và sửa file .xlsx
#    - Vấn đề & Rủi ro:
#      - UI phải thân thiện với người dùng low-tech, nhưng có thể mất thời gian phát triển và kiểm thử.
#      - Việc xây dựng một giao diện phức tạp có thể gặp vấn đề về hiệu năng khi file dữ liệu lớn.
#    - Giải pháp:
#      - Sử dụng các framework UI đơn giản như Gradio hoặc Streamlit để nhanh chóng tạo giao diện, đồng thời tối ưu hóa hiệu suất khi thao tác với file lớn.
#      - Thêm chức năng kiểm soát lỗi khi người dùng nhập dữ liệu không hợp lệ.
#
# 3. Cơ chế tự động lưu và undo/redo
#    - Vấn đề & Rủi ro:
#      - Cần đảm bảo quá trình lưu không làm gián đoạn hoạt động của ứng dụng, và việc cung cấp chức năng undo/redo có thể phức tạp nếu không thiết kế tốt.
#    - Giải pháp:
#      - Sử dụng cơ chế tự động lưu bất đồng bộ (autosave asynchronously) và thiết lập hệ thống lưu trữ tạm thời để hỗ trợ tính năng undo/redo.
#      - Thiết lập giới hạn về số lần undo/redo và cảnh báo người dùng nếu có vấn đề về bộ nhớ.
#
#  Hướng 2: Link Drive
# 1. Load file từ Google Drive thay vì local
#    - Vấn đề & Rủi ro:
#      - Phụ thuộc vào kết nối mạng và tốc độ truy cập Google Drive, có thể gây chậm trễ khi tải file.
#      - Vấn đề bảo mật khi truy cập file từ Drive.
#    - Giải pháp:
#      - Thiết lập cơ chế cache tạm thời các phiên bản của file từ Drive để hạn chế việc phải tải lại file nhiều lần.
#      - Sử dụng OAuth 2.0 để đảm bảo quyền truy cập an toàn vào file từ Google Drive và đảm bảo bảo mật dữ liệu.
#
#  Các phương án khác
#
#  Phương án 3: Tích hợp Google Sheets
# 1. Sử dụng Google Sheets thay vì Excel
#    - Vấn đề & Rủi ro:
#      - Phụ thuộc vào kết nối internet, nếu mạng yếu sẽ ảnh hưởng đến hiệu suất.
#      - Giới hạn kích thước và số lượng ô trong Google Sheets có thể là vấn đề với dữ liệu lớn.
#    - Giải pháp:
#      - Cài đặt hệ thống thông báo và thử lại khi gặp sự cố mạng để đảm bảo tính liên tục của dữ liệu.
#      - Chia nhỏ file dữ liệu thành nhiều bảng tính nhỏ hơn nếu dữ liệu quá lớn.
#
#  Phương án 4: Xây dựng API để cập nhật dữ liệu
# 1. Xây dựng API để quản lý và cập nhật dữ liệu
#    - Vấn đề & Rủi ro:
#      - Yêu cầu thêm nguồn lực để xây dựng và bảo trì API.
#      - Vấn đề bảo mật khi dữ liệu được truyền qua API.
#    - Giải pháp:
#      - Sử dụng framework như Flask hoặc FastAPI để phát triển API một cách nhanh chóng, và thiết lập hệ thống xác thực để đảm bảo bảo mật.
#      - Định kỳ kiểm tra và bảo trì API để đảm bảo hoạt động ổn định.
#
#  Phương án 5: Chuyển sang cơ sở dữ liệu (Database)
# 1. Chuyển từ file Excel sang cơ sở dữ liệu (SQLite, MySQL, v.v.)
#    - Vấn đề & Rủi ro:
#      - Đòi hỏi người dùng có kiến thức cơ bản về cơ sở dữ liệu, hoặc cần cung cấp giao diện dễ sử dụng.
#      - Có thể phức tạp hóa việc cài đặt và bảo trì ứng dụng.
#    - Giải pháp:
#      - Sử dụng cơ sở dữ liệu nhẹ như SQLite để tích hợp trực tiếp vào ứng dụng mà không yêu cầu cấu hình phức tạp.
#      - Xây dựng giao diện quản lý dữ liệu đơn giản, hỗ trợ các thao tác thêm, sửa, xóa dữ liệu mà không yêu cầu người dùng phải trực tiếp thao tác với cơ sở dữ liệu.
#
#  Phương án 6: Sử dụng hệ thống CMS (Content Management System)
# 1. Tích hợp CMS như WordPress hoặc một hệ thống quản lý nội dung tương tự để quản lý câu hỏi
#    - Vấn đề & Rủi ro:
#      - Chi phí triển khai và quản lý hệ thống CMS có thể cao hơn so với các phương án khác.
#      - Yêu cầu kiến thức cơ bản về quản lý hệ thống CMS.
#    - Giải pháp:
#      - Sử dụng các plugin có sẵn hoặc xây dựng plugin tùy chỉnh để tích hợp dễ dàng vào hệ thống hiện tại.
#      - Cung cấp hướng dẫn chi tiết để người dùng quản lý nội dung thông qua CMS mà không gặp khó khăn.
#
#  Phương án 7: Sử dụng giao diện Form-based
# 1. Xây dựng giao diện form-based để người dùng nhập câu hỏi trực tiếp
#    - Vấn đề & Rủi ro:
#      - Giao diện form có thể giới hạn về tính linh hoạt trong việc quản lý dữ liệu.
#      - Không tối ưu với người dùng cần nhập nhiều dữ liệu cùng lúc.
#    - Giải pháp:
#      - Thiết kế form thân thiện, với các mẫu câu hỏi và hướng dẫn rõ ràng để giúp người dùng nhập liệu nhanh chóng.
#      - Kết hợp với cơ chế tải lên file nếu người dùng cần nhập dữ liệu lớn.
#
#  Tóm lại:
# - Hướng 1 phù hợp nếu bạn muốn giữ lại cơ chế hiện tại và mở rộng giao diện để hỗ trợ người dùng low-tech.
# - Hướng 2 và Phương án 3 giúp việc quản lý file linh hoạt hơn bằng cách chuyển sang lưu trữ trên cloud.
# - Phương án 4, 5, 6 hướng tới việc tối ưu quản lý dữ liệu và cải thiện hiệu suất qua API, cơ sở dữ liệu, hoặc hệ thống CMS.
# - Phương án 7 sẽ cung cấp một giao diện nhập liệu đơn giản, dễ tiếp cận cho người dùng.

# %% [markdown]
# ### Hướng 2
# 1. Vẽ hướng
# ```
# CODE NÀY TÔI ĐÃ TRIỂN KHAI TRÊN SERVER, sau khi chạy sẽ trả ra 1 link UI cho người dùng truy cập vào link UI đó để mà làm bài kiểm tra. Có 1 vấn đề là:
# 1. Thay đổi cơ chế: "ấn START" thì mới load file thay vì sẽ load file khi khởi động code toàn bộ
# 2. Sử dụng phương án:
# - LOAD FILE TỪ link google sheet với link: "https://docs.google.com/spreadsheets/d/1t5RURrOdY6WF2xSCGzKEYyj22RXJZPanXgIBo-mAuYE/edit?usp=sharing"
# thay thế cho file: # file_path = r'Data_MarketingKit.xlsx'
#
# ```
# 2. Quan sát rủi ro - giải pháp:
# ```
# CÓ VẤN ĐỀ GÌ KHI TRIỂN KHAI CODE TRÊN SERVER KHÔNG (chỉ tập trung vào vấn đề đối với file google sheet, các vấn đề khác tạm thời bỏ qua)- giải thích tiếng việt
# ```
#
# - Xác thực và Uỷ quyền: GCP, file credentials.json
# - Giới hạn API Google Sheets API giới hạn số lượng yêu cầu trong thời gian nhất định.
# - Độ trễ khi đọc file từ GG sheets
# - Phụ thuộc vào kết nối mạng
#
# 2.1 Giải pháp: `1 con bot tự động tải file lúc 12h đêm từ google sheet xuống server`
# - URL gg sheet để ở giới hạn quyền truy cập cần credentials.json (dự kiến Cường, a An, chị Thu)
# - 12h đêm bot check xem có sự thay đổi nào không ở file gg sheet, nếu có thì tự động tải file xuống server và thông báo gửi tới mail "cuongmkmtpgoldfinch@gmail.com, abc@gmail.com" là đã load file thành công.
# -
#
# Vấn đề
# ```
# Sử dụng Google Sheets API's revision history để kiểm tra thay đổi chính xác hơn.
# Cân nhắc kiểm tra nhiều lần trong ngày hoặc sử dụng webhook để cập nhật real-time.
# Implement hệ thống backup và rollback cho dữ liệu.
# Tăng cường xử lý lỗi và retry logic.
# Sử dụng quản lý bí mật an toàn hơn cho credentials.
# Thêm monitoring và alerting để phát hiện vấn đề sớm.
# Cân nhắc sử dụng database thay vì file Excel để lưu trữ dữ liệu.
# ```
#
# 2.2 Vì người dùng: TÔI CẦN SỰ REAL TIME GIỮA GOOGLE SHEET VÀ LOCAL SERVER
# Giải pháp: `1 con bot tự động đồng bộ giữa file google sheet ở Drive với file excel ở local server`
# Vấn đề:
#
# Giải pháp này có vấn đề gì không?
# ```
# Các vấn đề gặp phải khi triển khai bot đồng bộ giữa Google Sheets và file Excel trên local server:
#
# 1. **Độ trễ (Latency)**: Đồng bộ có thể không hoàn toàn real-time do độ trễ giữa các lần cập nhật.
# 2. **Bảo mật (Security)**: Cần đảm bảo quyền truy cập an toàn vào Google Sheets và local server, tránh lỗ hổng bảo mật.
# 3. **Xung đột dữ liệu (Conflict Management)**: Dữ liệu có thể bị ghi đè hoặc xung đột khi nhiều người chỉnh sửa hoặc khi file Excel đang mở trên local server.
# 4. **Kết nối (Connectivity Issues)**: Phụ thuộc vào kết nối internet ổn định, dễ gặp gián đoạn đồng bộ khi mất kết nối.
# 5. **Hiệu suất (Performance)**: Đồng bộ liên tục với file lớn có thể gây tải nặng lên server, giảm hiệu suất.
# 6. **Quản lý phiên bản (Version Control)**: Khó theo dõi và quay lại phiên bản trước nếu xảy ra lỗi.
#
#
# ```

# %% [markdown]
# ### Hướng 1: Sửa cơ chế Start mới load file + Build New UI với chức năng chỉnh sừa file
#
# 1. Sửa cơ chế hiện tại của code cũ: Ấn `Start` mới bắt đầu đọc file.
# - Vấn đề là: còn việc chọn topic, ...
#
# Giải pháp
#
# 1.1
# ```
# - Khi chạy code trên server, hiển thị 1 nút là "LOAD FILE".
# - Chúng ta kick vào nút "LOAD FILE" -> Lúc này code mới bắt đầu đọc file_path = r'Data_MarketingKit.xlsx'
# - Sau khi đọc file xong, code chạy như bình thường trước đó.
# (thêm xử lý lỗi trong hàm load_file(), phản hồi người dùng khi load file thành công/thất bại)
# - Bug: TẠI SAO SAU KHI ẤN LOAD FILE, thì lại chỉ có: Load Status, Enter Your Name, Select Number of Questions 5-10-15-20. MÀ KO THẤY: Select Topic.
# Sau khi ấn nút `Start` thì bỏ thông báo 'Load Status'
# ```
#
# ```
# if not user_name_input or not topic_selector_input or not num_questions_input:
#     return gr.update(visible=True),  # Keep load_status visible
#
# return
#
# # cập nhật kết nối sự kiện cho nút "Start" để bao gồm load_status
#
# start_button.click(
#     ...,
#     load_status,
#     state
#
# ```

# %%
# import asyncio
# import aiohttp
# from datetime import datetime
# import pandas as pd
# import gradio as gr
# import json
# from openai import AsyncOpenAI, APIError, RateLimitError
# import os
# import random
# import tempfile
# from openpyxl import Workbook
# from openpyxl.utils.dataframe import dataframe_to_rows
# import threading
# import logging
# from functools import lru_cache
# from circuitbreaker import circuit

# logging.basicConfig(level=logging.INFO)
# logger = logging.getLogger(__name__)
# file_lock = threading.Lock()

# def load_quiz_data(file_path, sheet_name):
#     try:
#         df = pd.read_excel(file_path, sheet_name=sheet_name)
#         df = df[df['topic'].notna()]
#         questions = df['question'].tolist()
#         checking_answers = df['checking_answer'].tolist()
#         explain_answers = df['explain_answer'].tolist() if 'explain_answer' in df.columns else [None] * len(questions)
#         topics = df['topic'].tolist()
        
#         logger.info(f"Đã load dữ liệu từ sheet {sheet_name}. Số lượng câu hỏi: {len(questions)}")
#         return questions, checking_answers, explain_answers, topics
#     except Exception as e:
#         logger.error(f"Lỗi khi đọc dữ liệu từ sheet {sheet_name}: {str(e)}")
#         raise

# @circuit(failure_threshold=5, recovery_timeout=60)
# async def scoring_short_essay_questions(QUESTION, CHECKING_ANSWER, USER_ANSWER):
#     async with AsyncOpenAI(api_key="") as client:
#         prompt = f"""
#         Act: You are an expert at scoring short essay questions. 
#         You are provided with 1 QUESTION and 1 CHECKING ANSWER for that QUESTION. After USER enters the answer, you will check USER ANSWER with CHECKING ANSWER. 
#         Instructions: 
#         - point: check USER ANSWER with CHECKING ANSWER to score on a 5-point scale 
#         - comment: briefly in 2 sentences: the reason you gave such a score (in Vietnamese)
#         Output: JSON format with 2 keys: `point` and `comment`
#         QUESTION:
#         {QUESTION}
#         CHECKING ANSWER:
#         {CHECKING_ANSWER}
#         """
#         try:
#             async with asyncio.timeout(10):
#                 completion = await client.chat.completions.create(
#                     model="gpt-4o-mini",
#                     messages=[
#                         {"role": "system", "content": prompt},
#                         {"role": "user", "content": USER_ANSWER},
#                     ],
#                     temperature=0,
#                     max_tokens=6000,
#                 )
            
#             logger.info("Đã gửi yêu cầu chấm điểm đến OpenAI")
#             return json.loads(completion.choices[0].message.content)
#         except RateLimitError:
#             logger.warning("Rate limit exceeded. Retrying after a delay.")
#             await asyncio.sleep(5)
#             return await scoring_short_essay_questions(QUESTION, CHECKING_ANSWER, USER_ANSWER)
#         except APIError as e:
#             logger.error(f"OpenAI API error: {str(e)}")
#             raise
#         except Exception as e:
#             logger.error(f"Error in scoring: {str(e)}")
#             raise

# @lru_cache(maxsize=100)
# def cached_scoring(question, answer):
#     return asyncio.run(scoring_short_essay_questions(question, answer))

# async def quiz_logic(questions, checking_answers, explain_answers, questions_mc, questions_essay, user_answer, filtered_questions, state):
#     current_question_index = state["current_question_index"]
#     total_score = state["total_score"]
#     results = state["results"]
#     user_name = state["user_name"]
#     is_essay = state["filtered_is_essay_list"][current_question_index]
#     quiz_start_time = state["quiz_start_time"]
#     output_path = state["output_path"]
#     num_questions = state["num_questions"]

#     if user_answer:
#         if is_essay:
#             try:
#                 response = await scoring_short_essay_questions(questions[current_question_index], checking_answers[current_question_index], user_answer)
#                 point = response['point']
#                 comment = response['comment']
#                 full_answer = explain_answers[current_question_index]
#                 total_score += point
#                 assistant_response = f"- Point: {point}/5. {comment}\n- Câu trả lời tham khảo: \n\"\"\"\n{full_answer}\n\"\"\" \n"
#             except Exception as e:
#                 logger.error(f"Error in scoring essay question: {str(e)}")
#                 assistant_response = f"Có lỗi xảy ra khi chấm điểm: {str(e)}. Vui lòng thử lại."
#                 point = 0
#         else:
#             if user_answer.strip().upper() == checking_answers[current_question_index]:
#                 assistant_response = f"Đúng! \n{explain_answers[current_question_index]}" if explain_answers[current_question_index] else "Đúng! Get 1 point."
#                 point = 1
#                 total_score += 1
#             else:
#                 assistant_response = f"Sai! \n{explain_answers[current_question_index]}" if explain_answers[current_question_index] else "Sai! Get 0 point."
#                 point = 0

#         results.append({
#             'user_name': user_name,
#             'stt': current_question_index + 1,
#             'question_type': 'essay' if is_essay else 'mc',
#             'question': questions[current_question_index],
#             'user_answer': user_answer,
#             'point': point,
#             'assistant_response': assistant_response,
#         })
#         logger.info(f"Câu hỏi {current_question_index + 1} đã được trả lời. Điểm: {point}")
        
#         current_question_index += 1
#     else:
#         assistant_response = ""

#     if current_question_index < len(questions) and not pd.isna(questions[current_question_index]):
#         assistant_response += "\n \n ---------------------------CÂU HỎI---------------------------"
#         assistant_response += f"\n{questions[current_question_index]}"
#         state["current_question_index"] = current_question_index
#         state["total_score"] = total_score
#         state["results"] = results
#         return assistant_response, gr.update(visible=True), gr.update(visible=True), state, gr.update(visible=False)
#     else:
#         quiz_end_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#         for result in results:
#             result['time_start'] = quiz_start_time
#             result['time_end'] = quiz_end_time
#             result['total_score'] = total_score
        
#         df = pd.DataFrame(results)
        
#         with file_lock:
#             df.to_excel(output_path, index=False)
#         logger.info(f"File kết quả đã được lưu thành công tại: {output_path}")
        
#         num_mc = sum(1 for q in filtered_questions if q in questions_mc)
#         num_essay = sum(1 for q in filtered_questions if q in questions_essay)
#         max_possible_score = num_mc * 1 + num_essay * 5
#         assistant_response += f"\nTổng điểm của {user_name} là: {total_score}/{max_possible_score}"
#         state["current_question_index"] = current_question_index
#         state["total_score"] = total_score
#         state["results"] = results
#         return assistant_response, gr.update(visible=True), gr.update(visible=False), state, gr.update(visible=True, value=df)

# def create_quiz_interface(file_path, sheet_name_mc, sheet_name_essay, output_dir):
#     questions_mc, checking_answers_mc, explain_answers_mc, topics_mc = [], [], [], []
#     questions_essay, checking_answers_essay, explain_answers_essay, topics_essay = [], [], [], []
#     topics = []
#     questions = []
#     checking_answers = []
#     explain_answers = []


#     def load_file():
#         nonlocal questions_mc, checking_answers_mc, explain_answers_mc, topics_mc
#         nonlocal questions_essay, checking_answers_essay, explain_answers_essay, topics_essay
#         nonlocal topics, questions, checking_answers, explain_answers

#         try:
#             questions_mc, checking_answers_mc, explain_answers_mc, topics_mc = load_quiz_data(file_path, sheet_name_mc)
#             questions_essay, checking_answers_essay, explain_answers_essay, topics_essay = load_quiz_data(file_path, sheet_name_essay)
#             topics = list(set(topics_mc + topics_essay))
#             questions = questions_mc + questions_essay
#             checking_answers = checking_answers_mc + checking_answers_essay
#             explain_answers = explain_answers_mc + explain_answers_essay

#             logger.info("File loaded successfully")
#             return (
#                 gr.update(choices=topics, visible=True),  # Update topic_selector
#                 gr.update(visible=True),  # Update user_name_input
#                 gr.update(visible=True),  # Update num_questions
#                 gr.update(visible=True),  # Update start_button
#                 gr.update(visible=False), # Hide load_file_button
#                 gr.update(value="File loaded successfully!", visible=True)  # Update load_status
#             )
#         except Exception as e:
#             logger.error(f"Error loading file: {str(e)}")
#             return (
#                 gr.update(visible=False),  # Keep topic_selector hidden
#                 gr.update(visible=False),  # Keep user_name_input hidden
#                 gr.update(visible=False),  # Keep num_questions hidden
#                 gr.update(visible=False),  # Keep start_button hidden
#                 gr.update(visible=True),   # Keep load_file_button visible
#                 gr.update(value=f"Error loading file: {str(e)}", visible=True)  # Update load_status
#             )


#     custom_css = """
#     .total-score-right {
#         position: absolute;
#         top: 10px;
#         right: 10px;
#         width: auto !important;
#     }
#     """

#     with gr.Blocks() as demo:
#         gr.HTML(f"<style>{custom_css}</style>")
#         state = gr.State({
#             "current_question_index": 0,
#             "total_score": 0,
#             "results": [],
#             "user_name": "",
#             "selected_topic": "",
#             "filtered_questions": [],
#             "filtered_checking_answers": [],
#             "filtered_explain_answers": [],
#             "filtered_is_essay_list": [],
#             "quiz_start_time": "",
#             "output_path": "",
#             "num_questions": 5
#         })

#         load_file_button = gr.Button("LOAD FILE")
#         load_status = gr.Textbox(label="Load Status", visible=False)
#         user_name_input = gr.Textbox(label="Enter Your Name", visible=False)
#         topic_selector = gr.Dropdown(label="Select Topic", choices=topics, visible=False)
#         num_questions = gr.Dropdown(label="Select Number of Questions 5-10-15-20", choices=[1, 3, 5, 10, 15, 20], visible=False)
#         start_button = gr.Button("Start", visible=False)

#         response_box = gr.Textbox(label="Response", interactive=False, visible=False)
#         question_box = gr.Textbox(label="Question", interactive=False, visible=False)

#         user_input = gr.Textbox(label=f"Your Answer", visible=False)
#         results_table = gr.DataFrame(
#             label="Your results have been saved successfully",
#             interactive=False,
#             visible=False,
#             wrap=False
#         )
#         total_score_display = gr.Textbox(label=f"Total Score", value="0", interactive=False, visible=False, elem_classes="total-score-right")
#         save_status = gr.Textbox(label="Save Status", visible=False)
#         download_button = gr.Button("Download Results", visible=False)

#         def split_response_and_question(quiz_result):
#             parts = quiz_result.split("---------------------------CÂU HỎI---------------------------")
#             response = parts[0].strip() if len(parts) > 1 else ""
#             question = parts[1].strip() if len(parts) > 1 else quiz_result.strip()
#             return response, question
            
#         def start_quiz(user_name_input, topic_selector_input, num_questions_input, state):
#             if not user_name_input or not topic_selector_input or not num_questions_input:
#                 return (
#                     gr.update(value="Vui lòng nhập tên, chọn chủ đề và số câu hỏi trước khi bắt đầu.", visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=True),
#                     gr.update(visible=True),
#                     gr.update(visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     gr.update(visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     gr.update(visible=True),  # Keep load_status visible
#                     state
#                 )
#             state["user_name"] = user_name_input
#             state["selected_topic"] = topic_selector_input
#             state["num_questions"] = int(num_questions_input)
#             state["current_question_index"] = 0
#             state["total_score"] = 0
#             state["results"] = []
#             quiz_start_time = datetime.now()
#             state["quiz_start_time"] = quiz_start_time.strftime("%Y-%m-%d %H:%M:%S")
#             date_str = quiz_start_time.strftime("%d%m%Y")
#             file_safe_user_name = user_name_input.replace(" ", "")
#             file_safe_topic = topic_selector_input.replace(" ", "_")
#             state["output_path"] = os.path.join(output_dir, f"{file_safe_user_name}_{file_safe_topic}_{date_str}_results.xlsx")
#             mc_questions = [q for q, t in zip(questions_mc, topics_mc) if t == topic_selector_input]
#             essay_questions = [q for q, t in zip(questions_essay, topics_essay) if t == topic_selector_input]
#             num_mc = int(state["num_questions"] * 0.3)
#             num_essay = state["num_questions"] - num_mc
#             selected_mc = random.sample(mc_questions, min(num_mc, len(mc_questions)))
#             selected_essay = random.sample(essay_questions, min(num_essay, len(essay_questions)))
#             state["filtered_questions"] = selected_mc + selected_essay
#             random.shuffle(state["filtered_questions"])
#             state["filtered_checking_answers"] = [checking_answers[questions.index(q)] for q in state["filtered_questions"]]
#             state["filtered_explain_answers"] = [explain_answers[questions.index(q)] for q in state["filtered_questions"]]
#             state["filtered_is_essay_list"] = [q in questions_essay for q in state["filtered_questions"]]
#             quiz_result, response_visibility, user_input_visibility, state, results_visibility = asyncio.run(quiz_logic(
#                 state["filtered_questions"], state["filtered_checking_answers"], state["filtered_explain_answers"],
#                 questions_mc, questions_essay, "", state["filtered_questions"], state
#             ))
#             response, question = split_response_and_question(quiz_result)
            
#             logger.info(f"Quiz bắt đầu cho người dùng {user_name_input} với chủ đề {topic_selector_input}")
            
#             quiz_finished = state["current_question_index"] >= len(state["filtered_questions"])
            
#             return (
#                 gr.update(value=response, visible=True),
#                 gr.update(value=question, visible=True),
#                 gr.update(visible=False),
#                 gr.update(visible=False),
#                 gr.update(visible=False),
#                 gr.update(visible=not quiz_finished, label=f"Your Answer"),
#                 gr.update(visible=False),
#                 gr.update(value=f"{state['total_score']}", visible=True, label=f"Total Score - {user_name_input} - {topic_selector_input} - {num_questions_input} questions"),
#                 gr.update(visible=False),
#                 gr.update(visible=quiz_finished, value=f"File kết quả đã được lưu thành công tại: {state['output_path']}" if quiz_finished else ""),
#                 gr.update(visible=quiz_finished),
#                 gr.update(visible=False),  # Hide load_status
#                 state
#             )

#         async def handle_user_input(user_answer, state):
#             try:
#                 quiz_result, response_visibility, user_input_visibility, state, results_visibility = await quiz_logic(
#                     state["filtered_questions"], state["filtered_checking_answers"], state["filtered_explain_answers"],
#                     questions_mc, questions_essay, user_answer, state["filtered_questions"], state
#                 )
#                 response, question = split_response_and_question(quiz_result)
                
#                 is_quiz_finished = state["current_question_index"] >= len(state["filtered_questions"])
#                 if is_quiz_finished:
#                     return gr.update(value=quiz_result), gr.update(value=""), user_input_visibility, "", results_visibility, gr.update(value=f"{state['total_score']}"), gr.update(visible=is_quiz_finished), state
#                 else:
#                     return gr.update(value=response), gr.update(value=question), user_input_visibility, "", results_visibility, gr.update(value=f"{state['total_score']}", label=f"Total Score - {state['user_name']} - {state['selected_topic']} - {state['num_questions']} questions"), gr.update(visible=state["current_question_index"] >= len(state["filtered_questions"])), state

#             except IndexError:
#                 logger.error("IndexError occurred. This may be due to server restart.")
#                 error_message = "Lỗi: Server vừa được khởi động lại. Tiến trình làm bài của bạn đã bị gián đoạn. Vui lòng bắt đầu lại bài kiểm tra. Chúng tôi xin lỗi vì sự bất tiện này."
#                 return gr.update(value=error_message), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), state
#             except Exception as e:
#                 logger.error(f"An unexpected error occurred: {str(e)}")
#                 error_message = f"Đã xảy ra lỗi không mong đợi: {str(e)}. Vui lòng thử lại hoặc liên hệ hỗ trợ."
#                 return gr.update(value=error_message), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), state


#         load_file_button.click(
#             load_file,
#             outputs=[topic_selector, user_name_input, num_questions, start_button, load_file_button, load_status]
#         )

#         start_button.click(
#             start_quiz,
#             inputs=[user_name_input, topic_selector, num_questions, state],
#             outputs=[
#                 response_box,
#                 question_box,
#                 user_name_input,
#                 topic_selector,
#                 num_questions,
#                 user_input,
#                 results_table,
#                 total_score_display,
#                 start_button,
#                 save_status,
#                 download_button,
#                 load_status,   # cập nhật phần kết nối của sự kiện 
#                 state
#             ],
#             concurrency_limit=40
#         )

#         user_input.submit(
#             handle_user_input,
#             inputs=[user_input, state],
#             outputs=[response_box, question_box, user_input, user_input, results_table, total_score_display, download_button, state],
#             concurrency_limit=40
#         )

#         def download_results(results):
#             with tempfile.NamedTemporaryFile(mode='w+b', delete=False, suffix='.xlsx') as temp_file:
#                 wb = Workbook()
#                 ws = wb.active
#                 for r in dataframe_to_rows(results, index=False, header=True):
#                     ws.append([cell.encode('utf-8').decode('utf-8') if isinstance(cell, str) else cell for cell in r])
#                 wb.save(temp_file.name)
            
#             logger.info(f"Data saved to temporary file: {temp_file.name}")
#             return gr.File(value=temp_file.name, visible=True, label="Download Results")

#         download_button.click(
#             download_results,
#             inputs=[results_table],
#             outputs=[gr.File(label="Download Results", visible=False)]
#         )

#         demo.launch(share=True, server_name="0.0.0.0", server_port=25008)

# file_path = r'Data_MarketingKit.xlsx'
# sheet_name_mc = 'TN_P1P2'
# sheet_name_essay = 'TL_P1P2'
# output_dir = r'./out'
# create_quiz_interface(file_path, sheet_name_mc, sheet_name_essay, output_dir)

# %% [markdown]
# 1.
# ```
# - Sau khi ấn F5 thì file được load
# - Chỉ load data 1 lần khi F5 , ko load data khi ấn "Start"
#
# ```
#
# => Quay lại code cũ, hỏi 1 câu:
# ```
# Code này được để trên server và run 1 lần duy nhất.
# - Tôi đang thắc mắc là:
# +, File ở file_path chỉ được load 1 lần duy nhất chính là lúc code run trên server
# +, hay là mỗi khi F5 thì data ở file_path sẽ được load lại (vì tôi muốn là khi code run cố định chạy 1 lần - trên server, thì tôi vẫn có thể cập nhật chỉnh sửa file data `marketing_kit.xlsx` ở file path mà KO CẦN RUN LẠI CODE SERVER.
#
# Update code:
# 1. Khi chạy script thì data được load.
# Thêm các dòng print/log ở console để kiểm tra
# 2. Khi F5 thì data được load lại (tức load lại file_path)
# 3. Không cần load lại data khi ấn "Start"
#
# ```
#
#
# 2. Bug:
# - Khi load lại data, tôi đã thêm các cột mới vào mục "topic" => Topic của tôi lúc này không chỉ gồm: marketing_kit, mà có sale_kit, ...
# MÀ TẠI SAO UI, lúc (điền tên, chọn topic, chọn số câu hỏi rồi mới ấn Start) - tại sao UI này lại không cập nhật các topics mới để chọn.
# 3. Bug:
# - KHI MÀ sheet "TN" ở file @Data_MarketingKit.xlsx  thêm câu hỏi có cột "topic" mới thì bị LỖI NHƯ Ở TRÊN
# Còn khi sheet "TL" ở file đó thêm câu hỏi có cột "topic" mới thì ko lỗi
# - Nguyên nhân là do khi dữ liệu được tải lại, các danh sách như questions, checking_answers, explain_answers, topics_mc, topics_essay được cập nhật, nhưng state["filtered_is_essay_list"] không được cập nhật theo. Điều này dẫn đến sự không đồng bộ giữa dữ liệu và trạng thái của ứng dụng. Để khắc phục lỗi này, bạn cần đảm bảo rằng khi dữ liệu được tải lại, các trạng thái liên quan cũng được cập nhật đồng thời. Một cách tiếp cận có thể là tạo ra một hàm riêng để tạo ra state["filtered_is_essay_list"] dựa trên dữ liệu mới, và gọi hàm này mỗi khi dữ liệu được tải lại.
# => vấn đề sau cùng:
#
# ```
#
# Vấn đề là:
# - Khi sheet "TL" có câu hỏi với chủ đề "marketing", sheet "TN" ko có câu hỏi với chủ đề "marketing" => Ko lỗi.
# - Ngược lại: Khi sheet "TN" có câu hỏi với chủ đề "marketing", sheet "TL" ko có câu hỏi với chủ đề "marketing" => LỖI, ở dòng:
# ```
#   File "d:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\PRODUCT_THECOACH\TASK5_GPTschatbot_TestingSale\deploy\QuizApp_deploy1\app.py", line 116, in quiz_logic
#     is_essay = state["filtered_is_essay_list"][current_question_index]
#                ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# ```
# ```
#
#
# 4.
#
# 5. KIỂM TRA 1 LOẠT XEM CÓ LỖI GÌ KO?
# - cách tính điểm, cơ chế tính điểm
# - Cơ chế cập nhật câu hỏi, ...
# ```
# Trong trường hợp này, khi người dùng chọn 10 câu hỏi nhưng chỉ có tổng cộng 8 câu hỏi có sẵn (5 trắc nghiệm và 3 tự luận), hệ thống sẽ xử lý như sau:
#
# Số câu tự luận mong muốn: 7 (70% của 10)
# Số câu trắc nghiệm mong muốn: 3 (30% của 10)
# Tuy nhiên, do giới hạn số lượng câu hỏi có sẵn:
#
# Số câu tự luận thực tế: 3 (min(7, 3))
# Số câu trắc nghiệm thực tế: 5 (min(10 - 3, 5))
# Kết quả cuối cùng:
#
# Bài kiểm tra sẽ có tổng cộng 8 câu hỏi (3 tự luận và 5 trắc nghiệm).
# Hệ thống sẽ sử dụng tất cả các câu hỏi có sẵn.
# Người dùng sẽ nhận được ít câu hỏi hơn so với yêu cầu ban đầu (8 thay vì 10).
# Hệ thống sẽ tiếp tục với bài kiểm tra này, mặc dù không đạt được số lượng câu hỏi mong muốn ban đầu.
# ```

# %%
# import asyncio
# import aiohttp
# from datetime import datetime
# import pandas as pd
# import gradio as gr
# import json
# from openai import AsyncOpenAI, APIError, RateLimitError
# import os
# import random
# import tempfile
# from openpyxl import Workbook
# from openpyxl.utils.dataframe import dataframe_to_rows
# import threading
# import logging
# from functools import lru_cache
# from circuitbreaker import circuit

# logging.basicConfig(level=logging.INFO)
# logger = logging.getLogger(__name__)

# file_lock = threading.Lock()

# def update_topic_selector():
#     questions, checking_answers, explain_answers, topics, questions_mc, questions_essay, topics_mc, topics_essay = load_all_data(file_path, sheet_name_mc, sheet_name_essay)
#     new_topics = list(set(topics_mc + topics_essay))
#     return gr.update(choices=new_topics)


# def load_quiz_data(file_path, sheet_name):
#     logger.info(f"Loading data from file: {file_path}, sheet: {sheet_name}")
#     try:
#         df = pd.read_excel(file_path, sheet_name=sheet_name, engine='openpyxl')
#     except Exception as e:
#         logger.error(f"Lỗi khi đọc tệp Excel: {e}")
#         raise
#     df = df[df['topic'].notna()]
#     questions = df['question'].tolist()
#     checking_answers = df['checking_answer'].tolist()
#     explain_answers = df['explain_answer'].tolist() if 'explain_answer' in df.columns else [None] * len(questions)
#     topics = df['topic'].tolist()
#     logger.info(f"Loaded data from sheet {sheet_name}. Number of questions: {len(questions)}")
#     return questions, checking_answers, explain_answers, topics


# def load_all_data(file_path, sheet_name_mc, sheet_name_essay):
#     logger.info("Loading all data from Excel file...")
#     questions_mc, checking_answers_mc, explain_answers_mc, topics_mc = load_quiz_data(file_path, sheet_name_mc)
#     questions_essay, checking_answers_essay, explain_answers_essay, topics_essay = load_quiz_data(file_path, sheet_name_essay)
   
#     topics = list(set(topics_mc + topics_essay))
#     questions = questions_mc + questions_essay
#     checking_answers = checking_answers_mc + checking_answers_essay
#     explain_answers = explain_answers_mc + explain_answers_essay
    
#     logger.info(f"Total questions loaded: {len(questions)}")
#     logger.info("Data đã được load lại")  # Thêm dòng này
#     return questions, checking_answers, explain_answers, topics, questions_mc, questions_essay, topics_mc, topics_essay

# def update_filtered_is_essay_list(questions_mc, questions_essay, filtered_questions):
#     is_essay_list = [q in questions_essay for q in filtered_questions]
#     return is_essay_list



# @circuit(failure_threshold=5, recovery_timeout=60)
# async def scoring_short_essay_questions(QUESTION, CHECKING_ANSWER, USER_ANSWER):
#     async with AsyncOpenAI(api_key="") as client:
#         prompt = f"""
#         Act: You are an expert at scoring short essay questions. 
#         You are provided with 1 QUESTION and 1 CHECKING ANSWER for that QUESTION. After USER enters the answer, you will check USER ANSWER with CHECKING ANSWER. 

#         Instructions: 
#         - point: check USER ANSWER with CHECKING ANSWER to score on a 5-point scale 
#         - comment: briefly in 2 sentences: the reason you gave such a score (in Vietnamese)

#         Output: JSON format with 2 keys: `point` and `comment`
#         QUESTION:
#         {QUESTION}
#         CHECKING ANSWER:
#         {CHECKING_ANSWER}
#         """
#         try:
#             async with asyncio.timeout(10):
#                 completion = await client.chat.completions.create(
#                     model="gpt-4o-mini",
#                     messages=[
#                         {"role": "system", "content": prompt},
#                         {"role": "user", "content": USER_ANSWER},
#                     ],
#                     temperature=0,
#                     max_tokens=6000,
#                 )
            
#             logger.info("Đã gửi yêu cầu chấm điểm đến OpenAI")
#             return json.loads(completion.choices[0].message.content)
#         except RateLimitError:
#             logger.warning("Rate limit exceeded. Retrying after a delay.")
#             await asyncio.sleep(5)
#             return await scoring_short_essay_questions(QUESTION, CHECKING_ANSWER, USER_ANSWER)
#         except APIError as e:
#             logger.error(f"OpenAI API error: {str(e)}")
#             raise
#         except Exception as e:
#             logger.error(f"Error in scoring: {str(e)}")
#             raise

# @lru_cache(maxsize=100)
# def cached_scoring(question, answer):
#     return asyncio.run(scoring_short_essay_questions(question, answer))

# async def quiz_logic(questions, checking_answers, explain_answers, questions_mc, questions_essay, user_answer, filtered_questions, state):
#     try: 
#         current_question_index = state["current_question_index"]
#         total_score = state["total_score"]
#         results = state["results"]
#         user_name = state["user_name"]
#         is_essay = state["filtered_is_essay_list"][current_question_index]
#         quiz_start_time = state["quiz_start_time"]
#         output_path = state["output_path"]
#         num_questions = state["num_questions"]
#     except KeyError as e:
#         logger.error(f"KeyError in quiz_logic: {str(e)}")
#         logger.error(f"Current state: {state}")
#         raise
#     except Exception as e:
#         logger.error(f"Unexpected error in quiz_logic: {str(e)}")
#         raise

#     if user_answer:
#         if is_essay:
#             try:
#                 response = await scoring_short_essay_questions(questions[current_question_index], checking_answers[current_question_index], user_answer)
#                 point = response['point']
#                 comment = response['comment']
#                 full_answer = explain_answers[current_question_index]
#                 total_score += point
#                 assistant_response = f"- Point: {point}/5. {comment}\n- Câu trả lời tham khảo: \n\"\"\"\n{full_answer}\n\"\"\" \n"
#             except Exception as e:
#                 logger.error(f"Error in scoring essay question: {str(e)}")
#                 assistant_response = f"Có lỗi xảy ra khi chấm điểm: {str(e)}. Vui lòng thử lại."
#                 point = 0
#         else:
#             if user_answer.strip().upper() == checking_answers[current_question_index]:
#                 assistant_response = f"Đúng! \n{explain_answers[current_question_index]}" if explain_answers[current_question_index] else "Đúng! Get 1 point."
#                 point = 1
#                 total_score += 1
#             else:
#                 assistant_response = f"Sai! \n{explain_answers[current_question_index]}" if explain_answers[current_question_index] else "Sai! Get 0 point."
#                 point = 0

#         results.append({
#             'user_name': user_name,
#             'stt': current_question_index + 1,
#             'question_type': 'essay' if is_essay else 'mc',
#             'question': questions[current_question_index],
#             'user_answer': user_answer,
#             'point': point,
#             'assistant_response': assistant_response,
#         })

#         logger.info(f"Câu hỏi {current_question_index + 1} đã được trả lời. Điểm: {point}")
        
#         current_question_index += 1
#     else:
#         assistant_response = ""

#     if current_question_index < len(questions) and not pd.isna(questions[current_question_index]):
#         assistant_response += "\n \n ---------------------------CÂU HỎI---------------------------"
#         assistant_response += f"\n{questions[current_question_index]}"
#         state["current_question_index"] = current_question_index
#         state["total_score"] = total_score
#         state["results"] = results
#         return assistant_response, gr.update(visible=True), gr.update(visible=True), state, gr.update(visible=False)
#     else:
#         quiz_end_time = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
#         for result in results:
#             result['time_start'] = quiz_start_time
#             result['time_end'] = quiz_end_time
#             result['total_score'] = total_score
        
#         df = pd.DataFrame(results)
        
#         with file_lock:
#             df.to_excel(output_path, index=False)

#         logger.info(f"File kết quả đã được lưu thành công tại: {output_path}")
        
#         num_mc = sum(1 for q in filtered_questions if q in questions_mc)
#         num_essay = sum(1 for q in filtered_questions if q in questions_essay)
#         max_possible_score = state["num_mc"] * 1 + state["num_essay"] * 5

#         assistant_response += f"\nTổng điểm của {user_name} là: {total_score}/{max_possible_score}"
#         state["current_question_index"] = current_question_index
#         state["total_score"] = total_score
#         state["results"] = results
#         return assistant_response, gr.update(visible=True), gr.update(visible=False), state, gr.update(visible=True, value=df)



# def create_quiz_interface(file_path, sheet_name_mc, sheet_name_essay, output_dir):
#     logger.info("Creating quiz interface")
    
#     # Initial load of data
#     questions, checking_answers, explain_answers, topics, questions_mc, questions_essay, topics_mc, topics_essay = load_all_data(file_path, sheet_name_mc, sheet_name_essay)
#     logger.info("Data loaded successfully on initial load")

#     custom_css = """
#     .total-score-right {
#         position: absolute;
#         top: 10px;
#         right: 10px;
#         width: auto !important;
#     }
#     """

#     with gr.Blocks() as demo:
#         gr.HTML(f"<style>{custom_css}</style>")
#         state = gr.State({
#             "current_question_index": 0,
#             "total_score": 0,
#             "results": [],
#             "user_name": "",
#             "selected_topic": "",
#             "filtered_questions": [],
#             "filtered_checking_answers": [],
#             "filtered_explain_answers": [],
#             "filtered_is_essay_list": [],
#             "quiz_start_time": "",
#             "output_path": "",
#             "num_questions": 5, 
#             "num_mc": 0,
#             "num_essay": 0
#         })

#         user_name_input = gr.Textbox(label="Enter Your Name")
#         topic_selector = gr.Dropdown(label="Select Topic", choices=topics)
#         num_questions = gr.Dropdown(label="Select Number of Questions 5-10-15-20", choices=[1, 3, 5, 10, 15, 20])
#         start_button = gr.Button("Start")
        
#         response_box = gr.Textbox(label="Response", interactive=False, visible=False)
#         question_box = gr.Textbox(label="Question", interactive=False, visible=False)
        
#         user_input = gr.Textbox(label=f"Your Answer", visible=False)
#         results_table = gr.DataFrame(
#             label="Your results have been saved successfully",
#             interactive=False,
#             visible=False,
#             wrap=False
#         )
#         total_score_display = gr.Textbox(label=f"Total Score", value="0", interactive=False, visible=False, elem_classes="total-score-right")

#         save_status = gr.Textbox(label="Save Status", visible=False)
#         download_button = gr.Button("Download Results", visible=False)
#         demo.load(update_topic_selector, outputs=[topic_selector])
#         print("Đã load update_topic_selector with new dataset")

#         def split_response_and_question(quiz_result):
#             parts = quiz_result.split("---------------------------CÂU HỎI---------------------------")
#             response = parts[0].strip() if len(parts) > 1 else ""
#             question = parts[1].strip() if len(parts) > 1 else quiz_result.strip()
#             return response, question

            
#         def start_quiz(user_name_input, topic_selector_input, num_questions_input, state):
#             logger.info("Quiz started. Reloading data.")
#             questions, checking_answers, explain_answers, topics, questions_mc, questions_essay, topics_mc, topics_essay = load_all_data(file_path, sheet_name_mc, sheet_name_essay)
#             logger.info("Data reloaded for new quiz")

#             new_topics = list(set(topics_mc + topics_essay))
            
#             if not user_name_input or not topic_selector_input or not num_questions_input:
#                 return (
#                     gr.update(value="Vui lòng nhập tên, chọn chủ đề và số câu hỏi trước khi bắt đầu.", visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=True),
#                     gr.update(visible=True, choices=new_topics),
#                     gr.update(visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     gr.update(visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     state
#                 )            

#             state.update({
#                 "user_name": user_name_input,
#                 "selected_topic": topic_selector_input,
#                 "num_questions": int(num_questions_input),
#                 "current_question_index": 0,
#                 "total_score": 0,
#                 "results": []
#             })

#             quiz_start_time = datetime.now()
#             state["quiz_start_time"] = quiz_start_time.strftime("%Y-%m-%d %H:%M:%S")
#             date_str = quiz_start_time.strftime("%d%m%Y")
#             file_safe_user_name = user_name_input.replace(" ", "")
#             file_safe_topic = topic_selector_input.replace(" ", "_")

#             state["output_path"] = os.path.join(output_dir, f"{file_safe_user_name}_{file_safe_topic}_{date_str}_results.xlsx")

#             logger.info(f"Chủ đề đã chọn: {topic_selector_input}")

#             mc_questions = [q for q, t in zip(questions_mc, topics_mc) if t == topic_selector_input]
#             essay_questions = [q for q, t in zip(questions_essay, topics_essay) if t == topic_selector_input]
#             logger.info(f"Số câu trắc nghiệm: {len(mc_questions)}, Số câu tự luận: {len(essay_questions)}")

#             # Bước 3: Tính toán số câu hỏi cần chọn
#             total_questions = int(num_questions_input)
#             desired_essay = int(total_questions * 0.7)
#             desired_mc = total_questions - desired_essay

#             actual_essay = min(desired_essay, len(essay_questions))
#             actual_mc = min(total_questions - actual_essay, len(mc_questions))

#             state["num_mc"] = actual_mc
#             state["num_essay"] = actual_essay

#             logger.info(f"Chọn {actual_essay} câu tự luận và {actual_mc} câu trắc nghiệm")

#             # Bước 4: Chọn câu hỏi
#             selected_essay = random.sample(essay_questions, actual_essay) if essay_questions else []
#             selected_mc = random.sample(mc_questions, actual_mc) if mc_questions else []

#             state["filtered_questions"] = selected_essay + selected_mc
#             random.shuffle(state["filtered_questions"])

#             if not state["filtered_questions"]:
#                 return (
#                     gr.update(value="Không có câu hỏi nào cho chủ đề này. Vui lòng chọn chủ đề khác.", visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=True),
#                     gr.update(visible=True, choices=new_topics),
#                     gr.update(visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     gr.update(visible=True),
#                     gr.update(visible=False),
#                     gr.update(visible=False),
#                     state
#                 )

#             state["filtered_checking_answers"] = [checking_answers[questions.index(q)] for q in state["filtered_questions"]]
#             state["filtered_explain_answers"] = [explain_answers[questions.index(q)] for q in state["filtered_questions"]]
#             state["filtered_is_essay_list"] = [q in questions_essay for q in state["filtered_questions"]]

#             quiz_result, response_visibility, user_input_visibility, state, results_visibility = asyncio.run(quiz_logic(
#                 state["filtered_questions"], state["filtered_checking_answers"], state["filtered_explain_answers"],
#                 questions_mc, questions_essay, "", state["filtered_questions"], state
#             ))

#             response, question = split_response_and_question(quiz_result)
            
#             logger.info(f"Quiz bắt đầu cho người dùng {user_name_input} với chủ đề {topic_selector_input}")
            
#             quiz_finished = state["current_question_index"] >= len(state["filtered_questions"])
            
#             return (
#                 gr.update(value=response, visible=True),
#                 gr.update(value=question, visible=True),
#                 gr.update(visible=False),
#                 gr.update(visible=False, choices=new_topics),
#                 gr.update(visible=False),
#                 gr.update(visible=not quiz_finished, label=f"Your Answer"),
#                 gr.update(visible=False),
#                 gr.update(value=f"{state['total_score']}", visible=True, label=f"Total Score - {user_name_input} - {topic_selector_input} - {len(state['filtered_questions'])} questions"),
#                 gr.update(visible=False),
#                 gr.update(visible=quiz_finished, value=f"File kết quả đã được lưu thành công tại: {state['output_path']}" if quiz_finished else ""),
#                 gr.update(visible=quiz_finished),
#                 state
#             )


#         async def handle_user_input(user_answer, state):
#             try:
#                 quiz_result, response_visibility, user_input_visibility, state, results_visibility = await quiz_logic(
#                     state["filtered_questions"], state["filtered_checking_answers"], state["filtered_explain_answers"],
#                     questions_mc, questions_essay, user_answer, state["filtered_questions"], state
#                 )
#                 response, question = split_response_and_question(quiz_result)
                
#                 is_quiz_finished = state["current_question_index"] >= len(state["filtered_questions"])
#                 if is_quiz_finished:
#                     return gr.update(value=quiz_result), gr.update(value=""), user_input_visibility, "", results_visibility, gr.update(value=f"{state['total_score']}"), gr.update(visible=is_quiz_finished), state
#                 else:
#                     return gr.update(value=response), gr.update(value=question), user_input_visibility, "", results_visibility, gr.update(value=f"{state['total_score']}", label=f"Total Score - {state['user_name']} - {state['selected_topic']} - {state['num_questions']} questions"), gr.update(visible=state["current_question_index"] >= len(state["filtered_questions"])), state

#             except IndexError:
#                 logger.error("IndexError occurred. This may be due to server restart.")
#                 error_message = "Lỗi: Server vừa được khởi động lại. Tiến trình làm bài của bạn đã bị gián đoạn. Vui lòng bắt đầu lại bài kiểm tra. Chúng tôi xin lỗi vì sự bất tiện này."
#                 return gr.update(value=error_message), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), state
#             except Exception as e:
#                 logger.error(f"An unexpected error occurred: {str(e)}")
#                 error_message = f"Đã xảy ra lỗi không mong đợi: {str(e)}. Vui lòng thử lại hoặc liên hệ hỗ trợ."
#                 return gr.update(value=error_message), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), gr.update(), state



#         start_button.click(
#             start_quiz,
#             inputs=[user_name_input, topic_selector, num_questions, state],
#             outputs=[
#                 response_box,
#                 question_box,
#                 user_name_input,
#                 topic_selector,  # Đảm bảo topic_selector nằm trong danh sách outputs
#                 num_questions,
#                 user_input,
#                 results_table,
#                 total_score_display,
#                 start_button,
#                 save_status,
#                 download_button,
#                 state
#             ],
#             concurrency_limit=40
#         )

#         user_input.submit(
#             handle_user_input,
#             inputs=[user_input, state],
#             outputs=[response_box, question_box, user_input, user_input, results_table, total_score_display, download_button, state],
#             concurrency_limit=40
#         )

#         def download_results(results):
#             with tempfile.NamedTemporaryFile(mode='w+b', delete=False, suffix='.xlsx') as temp_file:
#                 wb = Workbook()
#                 ws = wb.active
#                 for r in dataframe_to_rows(results, index=False, header=True):
#                     ws.append([cell.encode('utf-8').decode('utf-8') if isinstance(cell, str) else cell for cell in r])
#                 wb.save(temp_file.name)
            
#             logger.info(f"Data saved to temporary file: {temp_file.name}")
#             return gr.File(value=temp_file.name, visible=True, label="Download Results")

#         download_button.click(
#             download_results,
#             inputs=[results_table],
#             outputs=[gr.File(label="Download Results", visible=False)]
#         )

#         demo.launch(share=True, server_name="0.0.0.0", server_port=25008)


# # Main execution
# # Main execution
# if __name__ == "__main__":
#     file_path = r'Data_MarketingKit.xlsx'
#     sheet_name_mc = 'TN_P1P2'
#     sheet_name_essay = 'TL_P1P2'
#     output_dir = r'./out'

#     logger.info("Starting quiz application")
#     create_quiz_interface(file_path, sheet_name_mc, sheet_name_essay, output_dir)

# %% [markdown]
# 2. Build UI Gradio mới:
# - Đọc file .xlsx từ local server lên UI
# - Thực hiện chỉnh sửa File trên UI, chỉ cần các chức năng chỉnh sửa cơ bản: ctrl C, ctrl V, ctrl Z
# - Hoàn thiện xong thì nhấn submit để lưu file
# - Sau khi ấn submit file được cập nhật trên local server đè lên file cũ.
# - Thông báo trên UI: đã lưu thành công file
# - Thêm lỗi error nếu server bị khởi động lại
# - ...
#
#
# ```
# Phân loại:
# - Front-end (Phía người dùng):
#
#     HTML
#     CSS
#     JavaScript (chạy trên trình duyệt)
#
# - Back-end (Phía máy chủ):
#
#     Flask (Python)
#     Node.js
#     JavaScript (khi chạy trên Node.js)
# ```

# %% [markdown]
# ### Hướng 3: UI link tới gg sheet, chỉnh sửa trên đó, Ấn đồng bộ để đồng bộ về file trên server
#
# 1. Down đồng bộ data từ google sheet (chế độ xem) -> xuống file .xlsx trên server.
# 2. Chỉnh sửa markdown
# - Chỉnh sửa chữ trên button
# - thêm ghi chú vào UI như nào. Kiểu nhắc người dùng "ấn đồng bộ sau khi đã chỉnh sửa xong trên file excel"
#
# Gửi idea a Trúc:
# ```
# Em định build như này, sếp xem thử ổn hông ạ.
# - Ấn vào kia sẽ link tới gg sheet. Chỉnh sửa trực tiếp từ gg sheet
# - Sửa xong ấn bắt đầu đồng bộ. (tầm 2-3s là xong).
#
# Giải pháp này ngăn được các lỗi khó kiểm soát nếu để tự động đồng bộ. ^^
# ```
#
# 3. Xử lý ngoại lệ, dự trù lỗi
# (
# - Internet connection check
# - File download verification
# - Write permission check
# - Specific exception handling for various potential issues
# )
#
#
# 4. Gửi thông báo team AI
# ```
# @Tô Trường An  anh ơi.
#
# Em đã build giải pháp để chỉnh sử, thêm bớt câu hỏi.
# - Anh chị sẽ chỉnh sửa trực tiếp trên 1 file google sheet cố định: hiện đang là file cũ của team mình (https://docs.google.com/spreadsheets/d/1t5RURrOdY6WF2xSCGzKEYyj22RXJZPanXgIBo-mAuYE/edit?usp=sharing)
# - Chỉnh sửa xong, anh chị ấn "ĐỒNG BỘ" để cập nhật vào data trong server.
#
# Cases:
# +, anh chị muốn thay đổi file google sheet khác => thì em có thể build thêm ô để nhập "LINK GOOGLE SHEET" mới
# (cơ mà em recommend nên cố định luôn 1 google sheet từ đầu, để tránh được 1 số lỗi nhập liệu ngoài ý muốn ạ).
#
# ------------
# Tầm chiều em sẽ đẩy lên server. Em sẽ gửi link anh test thử ạ. anh @Tô Trường An
# ```

# %%
# import gradio as gr
# import gdown
# import shutil
# import os

# def sync_data(button):
#     # URL để xuất Google Sheet dưới dạng tệp Excel
#     drive_file_url = "https://docs.google.com/spreadsheets/d/1t5RURrOdY6WF2xSCGzKEYyj22RXJZPanXgIBo-mAuYE/export?format=xlsx"
#     server_file_path = r"D:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\PRODUCT_THECOACH\TASK5_GPTschatbot_TestingSale\deploy\QuizApp_deploy1\Data_MarketingKit.xlsx"
    
#     try:
#         # Tải file từ Google Drive
#         temp_file = "temp_file.xlsx"
#         gdown.download(drive_file_url, temp_file, quiet=False)
        
#         # Đồng bộ với file trên server
#         shutil.copy(temp_file, server_file_path)
        
#         # Xóa file tạm
#         os.remove(temp_file)
        
#         return f"Đã đồng bộ dữ liệu từ Google Drive với file trên server ({server_file_path})"
#     except Exception as e:
#         return f"Lỗi khi đồng bộ dữ liệu: {str(e)}"

# # Tạo giao diện Gradio
# iface = gr.Interface(
#     fn=sync_data,
#     inputs=gr.Button("ĐỒNG BỘ DATA"),
#     outputs="text"
# )

# # Chạy ứng dụng
# iface.launch()

# %%
# import gradio as gr
# import gdown
# import shutil
# import os
# import requests
# import random

# def sync_data(button):
#     drive_file_url = "https://docs.google.com/spreadsheets/d/1t5RURrOdY6WF2xSCGzKEYyj22RXJZPanXgIBo-mAuYE/export?format=xlsx"
#     server_file_path = r"D:\OneDrive - Hanoi University of Science and Technology\ITE10-DS&AI-HUST\Learn&Task\PRODUCT_THECOACH\TASK5_GPTschatbot_TestingSale\deploy\QuizApp_deploy1\Data_MarketingKit.xlsx"

#     try:
#         # Simulate a server restart (1 in 10 chance)
#         if random.random() < 0.1:
#             raise Exception("Server đang khởi động lại. Vui lòng thử lại sau vài phút.")

#         # Check internet connection
#         requests.get("https://www.google.com", timeout=5)
        
#         # Download file from Google Drive
#         temp_file = "temp_file.xlsx"
#         gdown.download(drive_file_url, temp_file, quiet=False)
        
#         if not os.path.exists(temp_file):
#             raise FileNotFoundError("Không thể tải file từ Google Drive")
        
#         # Check write permissions
#         if not os.access(os.path.dirname(server_file_path), os.W_OK):
#             raise PermissionError(f"Không có quyền ghi vào thư mục {os.path.dirname(server_file_path)}")
        
#         # Sync with server file
#         shutil.copy(temp_file, server_file_path)
        
#         # Remove temp file
#         os.remove(temp_file)
        
#         return f"Đã đồng bộ dữ liệu từ Google Drive với file trên server ({server_file_path})"
#     except requests.ConnectionError:
#         return "Lỗi: Không thể kết nối internet. Vui lòng kiểm tra kết nối mạng."
#     except gdown.exceptions.DownloadError as e:
#         return f"Lỗi khi tải file từ Google Drive: {str(e)}"
#     except FileNotFoundError as e:
#         return str(e)
#     except PermissionError as e:
#         return str(e)
#     except shutil.Error as e:
#         return f"Lỗi khi sao chép file: {str(e)}"
#     except OSError as e:
#         return f"Lỗi hệ thống: {str(e)}"
#     except Exception as e:
#         return f"Lỗi: {str(e)}"

# # Tạo một giao diện Gradio sử dụng Blocks với chủ đề Soft
# with gr.Blocks(theme=gr.themes.Soft()) as demo:
    
#     gr.Markdown("<h1 style='text-align: center;'>Ứng dụng Đồng bộ Dữ liệu</h1>")

#     gr.Button("Ấn vào đây => Chỉnh sửa trực tiếp `link google sheet`", link="https://docs.google.com/spreadsheets/d/1t5RURrOdY6WF2xSCGzKEYyj22RXJZPanXgIBo-mAuYE/edit")
#     # Thêm ghi chú nhắc nhở người dùng
#     gr.Markdown("**Lưu ý:** Sau khi chỉnh sửa xong trên Google Sheet. Hãy ấn nút bên dưới để đồng bộ dữ liệu lên server.")

#     # Tạo một hàng chứa các nút điều khiển
#     with gr.Row():
#         sync_button = gr.Button("Bắt đầu Đồng bộ", variant="primary") # Tạo nút "Bắt đầu Đồng bộ" với kiểu primary

#     # Tạo một hộp văn bản để hiển thị trạng thái, có 5 dòng
#     output = gr.Textbox(label="Trạng thái", lines=5)

#     # Khi nút đồng bộ được nhấn, gọi hàm sync_data và hiển thị kết quả trong output
#     sync_button.click(sync_data, outputs=output)

# # Khởi chạy ứng dụng Gradio
# demo.launch()

# %% [markdown]
# ### Viết bài
#
# Bài viết 30 - viết từ TASK THỰC TẾ "BUILD app chấm điểm trắc nghiệm và tự động với cơ chế cập nhật được câu hỏi mới đơn giản cho team SALEs"
# +, USER DỄ DÙNG
# +, HỆ THỐNG ĐƠN GIẢN, NHƯNG ĐẢM BẢO DỄ DÀNG SCALE?  (cái này thì mình hiện chưa làm được, vì gradio build UI khá tù và khó scales).
# ```
# Bài toán :
# - sau khi đã build xong 1 UI cho bài hệ thống chấm điểm trắc nghiệm và tự luận xài Gradio với file câu hỏi excel có sẵn được đặt trên server.
# - bên admin muốn là có 1 cách để cập nhật câu hỏi, tránh việc mỗi lần cập nhật câu hỏi lại phải chạy lại code "Hệ thống chấm điểm tự động" trên server.
# ------
# ```
# => Tìm kiếm các giải pháp và DỰ TRÙ RỦI RO.
# 1. `### Hướng 1: Sửa cơ chế Start mới load file + Build New UI với chức năng chỉnh sừa file trên đó`
# => Vấn đề là: build new UI phức tạp, load file excel lên UI chỉnh sửa thì khó vì gradio hỗ trợ kém
#
# 2. `### Hướng 2: Xây cơ chế tự động script tự động đồng bộ giữa Google Sheet data với file .excel ở local server`.
# - Nếu đặt tự động đồng bộ 12h đêm thì ban ngày muốn update gấp thì sao
# - Còn nếu mà kiểu cập nhật real-time thì quá nhiều vấn đề về API đồng bộ, giới hạn đồng bộ nếu gọi API google sheet nhiều.
# + với nhiều rủi ro bug ngoại lệ.
#
# 3. `### Hướng 3: Trong lúc quay trở lại làm hướng 1 thấy gradio ko show được file local excel`.
# => KẾT HỢP HƯỚNG 1 VÀ HƯỚNG 2:
# +, Chỉnh sửa trực tiếp vẫn trên google sheet
# +, Thay vì TỰ ĐỘNG ĐỒNG BỘ thì build 1 UI.
# "ĐỒNG BỘ google sheet với excel local server" khi ấn nút "ĐỒNG BỘ"
# =>
# - đảm bảo data luôn mới.
# - UI lại đơn giản. Người dùng lại tiện dễ dùng
